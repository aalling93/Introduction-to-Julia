# %%
f(x)  = x+3
# Out:
# f (generic function with 1 method)

# %%
g(x) = x * 3
# Out:
# g (generic function with 1 method)

# %%
g(f(3))
# Out:
# 18

# %% [markdown]
# so, in pything this would be
#
# 1)  y = 3+3 = 6
# 2) return y = 6
# 3)  z = y*3 = 18
# 4) reutrn z

# %%
@code_llvm debuginfo=:none g(3)
# Out:
# define i64 @julia_g_1232(i64 signext %0) #0 {
# top:
#   %1 = shl i64 %0, 1
#   ret i64 %1
# }

# %% [markdown]
# However, this is not the case for julia. It uses low level virtual machine language for the computer to read.
#
# It takes a number, multiply
#
#
# It has lerned that f(x) can be removed. So it is stille easy for us to write the code and have an overview, but it does not slow it down!

# %% [markdown]
# Look, we can even use freek letters

# %%
𝜎  = 10
# Out:
# 10

# %%
𝜎
# Out:
# 10

# %%
abstract type Animal end 
struct Fox <: Animal weight::Float64 end
struct Chicken <: Animal weight::Float64 end

# %%
F = Fox(3.2)
Bigbird = Chicken(32.1)
# Out:
# Chicken(32.1)

# %%
combined_weight(A1::Animal, A2::Animal) = A1.weight + A2.weight
# Out:
# combined_weight (generic function with 1 method)

# %%
include("varibles.jl")
# Out:
# 2

# %%
var_y
# Out:
# 2

# %%
struct Peoples 
    name::String
    height::Float64
    year_of_birth::Int64
    fast::Bool
end

# %%
fieldnames(Peoples)
# Out:
# (:name, :height, :year_of_birth, :fast)

# %%
kristian = Peoples("kritian", 189.5,1993,true)
gustav = Peoples("gustav", 179.5,1996,false)
# Out:
# Peoples("gustav", 179.5, 1996, false)

# %%
kristian.fast
# Out:
# true

# %% [markdown]
# We cannot chagne struct. they are immutable. But they are faster than mutable struct.. therefore use them when you can

# %%
mutable struct MutableLanguage 
    name::String
    title::String
    year_of_birth::Int64
    fast::Bool
end

# %%
julia_mutable = MutableLanguage("Julia", "Rapidus", 2012, true)
# Out:
# MutableLanguage("Julia", "Rapidus", 2012, true)

# %%
gustav.name
# Out:
# "gustav"

# %%
gustav.name = "Gustav"
# Out:
# setfield!: immutable struct of type Peoples cannot be changed
#
#
#
# Stacktrace:
#
#  [1] setproperty!(x::Peoples, f::Symbol, v::String)
#
#    @ Base ./Base.jl:39
#
#  [2] top-level scope
#
#    @ ~/Documents/phd/coding/Introduction-to-Julia/my_own.ipynb:1

# %%
julia_mutable.name = "Julia"
# Out:
# "Julia"

# %%
julia_mutable.name
# Out:
# "Julia"

# %% [markdown]
# Definer hvilken type

# %%
function round_number(x::Float64) 
    return round(x)
end
# Out:
# round_number (generic function with 1 method)

# %%
function round_number(x::AbstractFloat) 
    return round(x)
end
# Out:
# round_number (generic function with 2 methods)

# %%
Base.show(io::IO, l::MutableLanguage) = print(
    io, l.name, ", ",
    2021 − l.year_of_birth, " years old, ",
    "has the following titles: ", l.title
)

# %%
julia_mutable
# Out:
# Julia, 9 years old, has the following titles: Rapidus

# %%
function add_multiply(x, y) 
    addition = x + y 
    multiplication = x * y
    return addition, multiplication
end
# Out:
# add_multiply (generic function with 1 method)

# %%
first(return_2)
# Out:
# 3

# %%
return_2[2]
# Out:
# 2

# %%
real is both int and float
# Out:
# syntax: extra token "is" after end of expression
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/phd/coding/Introduction-to-Julia/my_own.ipynb:1

# %%
function logarithm(x::Real; base::Real=2.7182818284590) 
    return log(base, x)
end
# Out:
# logarithm (generic function with 1 method)

# %%
map(x -> 2.7182818284590^x, logarithm(2))
# Out:
# 2.0

# %%
map(2)
# Out:
# MethodError: objects of type Int64 are not callable
#
# Maybe you forgot to use an operator such as *, ^, %, / etc. ?
#
#
#
# Stacktrace:
#
#  [1] map(f::Int64)
#
#    @ Base ./abstractarray.jl:2920
#
#  [2] top-level scope
#
#    @ ~/Documents/phd/coding/Introduction-to-Julia/my_own.ipynb:1

# %%
return_2 = add_multiply(1, 2)
# Out:
# (3, 2)

# %%
logarithm(2)
# Out:
# 0.6931471805599569

# %%
logarithm.([2,2])
# Out:
# 2-element Vector{Float64}:
#  0.6931471805599569
#  0.6931471805599569

# %% [markdown]
# HGvis man arbejder med store data strukturer vil man ikke have en stor overhead.
# Så er BAND operatorerne gode!!!
#
# Disse ændrer inputtet til en funktion.

# %%
function add_one!(V) 
    for i in 1:length(V)
        V[i] += 1 
    end 
    return nothing 
end
# Out:
# add_one! (generic function with 1 method)

# %%
a = " 
sometheongasd
asd
"
# Out:
# " \nsometheongasd\nasd\n"

# %%
println(a)
# Out:
#
# sometheongasd
# asd

# %%
a = "1"
if tryparse(Int64, a)
    a = parse(Int64, a)
end
# Out:
# TypeError: non-boolean (Int64) used in boolean context
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/phd/coding/Introduction-to-Julia/my_own.ipynb:2

# %%
a = tryparse(Int64, a)
# Out:
# 1

# %%
a
# Out:
# 1

# %%
tryparse(Int64, "A very non−numeric string")

# %%
# Out:
# ArgumentError: invalid base 10 digit 'A' in "A very non−numeric string"
#
#
#
# Stacktrace:
#
#  [1] tryparse_internal(#unused#::Type{Int64}, s::String, startpos::Int64, endpos::Int64, base_::Int64, raise::Bool)
#
#    @ Base ./parse.jl:137
#
#  [2] parse(::Type{Int64}, s::String; base::Nothing)
#
#    @ Base ./parse.jl:241
#
#  [3] parse(::Type{Int64}, s::String)
#
#    @ Base ./parse.jl:240
#
#  [4] top-level scope
#
#    @ ~/Documents/phd/coding/Introduction-to-Julia/my_own.ipynb:1

# %%
println(uppercase(a))
# Out:
#
# SOMETHEONGASD
# ASD

# %%
function naming(x)

    
    return  (first_output=x, second_output=3.14+x, s="Julia")
end
# Out:
# naming (generic function with 1 method)

# %%
function naming(x)
    first_output = x
    second_output = 322+x
    
    
    return  (first_output=x, second_output=3.14+x, s="Julia")
end

# %%
b = naming(3)
# Out:
# (first_output = 3, second_output = 6.140000000000001, s = "Julia")

# %%
b.s
# Out:
# "Julia"
